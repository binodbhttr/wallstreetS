# %%
import random
import numpy as np
from matplotlib import pyplot as plt

'''
x=np.zeros(1000)

for i in range(len(x)):
    x[i]=np.random.normal(0.1,10,1)

'''   
#plt.hist(x,bins=10)

initial_stocks=0
stock_price=10
portfolio=0
cost=0
total_days=200
price_history=np.zeros(total_days)
days=np.arange(0,total_days,1)
for i in range(total_days):
    percentage_change=np.random.normal(0.040270365328342904,2.8928265807635243,1)[0]
    stock_price=stock_price+(stock_price*percentage_change*0.01)
    price_history[i]=stock_price
    print(f"Day: {i} Stock Price is {stock_price}")
    if percentage_change<20:
        print("\n###### WARNING ######")
        print("Red Day: Price changed by: ",percentage_change,"%")
        print("stock price is",stock_price)
        print("Let's buy just 3 stocks")
        buy=3
        cost+=buy*stock_price
        portfolio+=3
        print("Now total stocks in our portfolio is: ",portfolio)
        print("\n")
    
print("\n\nTotal stocks bought",portfolio)
print("Total cost",cost)
cost_basis=cost/portfolio
print(f"Cost per stock ={cost_basis}")
print("Current stock price:",stock_price)


plt.plot(days,price_history)
# Out:
# Day: 0 Stock Price is 9.513676364292426
#
# ###### WARNING ######
# Red Day: Price changed by:  -4.8632363570757375 %
# stock price is 9.513676364292426
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  3
#
#
# Day: 1 Stock Price is 9.258156863675184
#
# ###### WARNING ######
# Red Day: Price changed by:  -2.6858124118692888 %
# stock price is 9.258156863675184
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  6
#
#
# Day: 2 Stock Price is 8.920055466028725
#
# ###### WARNING ######
# Red Day: Price changed by:  -3.6519298886910936 %
# stock price is 8.920055466028725
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  9
#
#
# Day: 3 Stock Price is 8.869686312027694
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.5646731031309868 %
# stock price is 8.869686312027694
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  12
#
#
# Day: 4 Stock Price is 9.172074709854327
#
# ###### WARNING ######
# Red Day: Price changed by:  3.4092344102020893 %
# stock price is 9.172074709854327
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  15
#
#
# Day: 5 Stock Price is 9.636063428680183
#
# ###### WARNING ######
# Red Day: Price changed by:  5.058710635308663 %
# stock price is 9.636063428680183
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  18
#
#
# Day: 6 Stock Price is 9.646815496857544
#
# ###### WARNING ######
# Red Day: Price changed by:  0.11158154216128394 %
# stock price is 9.646815496857544
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  21
#
#
# Day: 7 Stock Price is 9.58566083138389
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.63393630254019 %
# stock price is 9.58566083138389
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  24
#
#
# Day: 8 Stock Price is 9.273520784960935
#
# ###### WARNING ######
# Red Day: Price changed by:  -3.2563226668838032 %
# stock price is 9.273520784960935
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  27
#
#
# Day: 9 Stock Price is 9.284550813492642
#
# ###### WARNING ######
# Red Day: Price changed by:  0.11894110971955693 %
# stock price is 9.284550813492642
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  30
#
#
# Day: 10 Stock Price is 9.23212968934232
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.5646059265908837 %
# stock price is 9.23212968934232
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  33
#
#
# Day: 11 Stock Price is 9.216590823071316
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.16831291147201358 %
# stock price is 9.216590823071316
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  36
#
#
# Day: 12 Stock Price is 9.237582899236093
#
# ###### WARNING ######
# Red Day: Price changed by:  0.22776400263131083 %
# stock price is 9.237582899236093
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  39
#
#
# Day: 13 Stock Price is 9.035265715196346
#
# ###### WARNING ######
# Red Day: Price changed by:  -2.190152838103119 %
# stock price is 9.035265715196346
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  42
#
#
# Day: 14 Stock Price is 8.915628461385236
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.3241143933364607 %
# stock price is 8.915628461385236
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  45
#
#
# Day: 15 Stock Price is 9.305035762473494
#
# ###### WARNING ######
# Red Day: Price changed by:  4.367693234131873 %
# stock price is 9.305035762473494
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  48
#
#
# Day: 16 Stock Price is 10.084560707246107
#
# ###### WARNING ######
# Red Day: Price changed by:  8.377452431901197 %
# stock price is 10.084560707246107
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  51
#
#
# Day: 17 Stock Price is 10.022284876355894
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.6175363776179812 %
# stock price is 10.022284876355894
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  54
#
#
# Day: 18 Stock Price is 10.143774150062683
#
# ###### WARNING ######
# Red Day: Price changed by:  1.2121913835576654 %
# stock price is 10.143774150062683
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  57
#
#
# Day: 19 Stock Price is 9.694950543352057
#
# ###### WARNING ######
# Red Day: Price changed by:  -4.424621448298429 %
# stock price is 9.694950543352057
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  60
#
#
# Day: 20 Stock Price is 10.139488955724266
#
# ###### WARNING ######
# Red Day: Price changed by:  4.585257143751329 %
# stock price is 10.139488955724266
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  63
#
#
# Day: 21 Stock Price is 10.118963495586783
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.20243091369901306 %
# stock price is 10.118963495586783
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  66
#
#
# Day: 22 Stock Price is 9.722291985655447
#
# ###### WARNING ######
# Red Day: Price changed by:  -3.9200804519587096 %
# stock price is 9.722291985655447
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  69
#
#
# Day: 23 Stock Price is 10.252764453530656
#
# ###### WARNING ######
# Red Day: Price changed by:  5.456249088773334 %
# stock price is 10.252764453530656
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  72
#
#
# Day: 24 Stock Price is 9.180278368723357
#
# ###### WARNING ######
# Red Day: Price changed by:  -10.460457661620975 %
# stock price is 9.180278368723357
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  75
#
#
# Day: 25 Stock Price is 9.159393260438671
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.22749972763178802 %
# stock price is 9.159393260438671
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  78
#
#
# Day: 26 Stock Price is 9.404789346827826
#
# ###### WARNING ######
# Red Day: Price changed by:  2.679174039279127 %
# stock price is 9.404789346827826
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  81
#
#
# Day: 27 Stock Price is 9.538787070461542
#
# ###### WARNING ######
# Red Day: Price changed by:  1.4247817648240226 %
# stock price is 9.538787070461542
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  84
#
#
# Day: 28 Stock Price is 9.56963938276412
#
# ###### WARNING ######
# Red Day: Price changed by:  0.323440622740368 %
# stock price is 9.56963938276412
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  87
#
#
# Day: 29 Stock Price is 9.511454719848842
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.6080131192829793 %
# stock price is 9.511454719848842
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  90
#
#
# Day: 30 Stock Price is 9.604300225309718
#
# ###### WARNING ######
# Red Day: Price changed by:  0.9761441146023947 %
# stock price is 9.604300225309718
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  93
#
#
# Day: 31 Stock Price is 9.236388088582205
#
# ###### WARNING ######
# Red Day: Price changed by:  -3.8307021656608935 %
# stock price is 9.236388088582205
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  96
#
#
# Day: 32 Stock Price is 9.201291799598778
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.379978500760625 %
# stock price is 9.201291799598778
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  99
#
#
# Day: 33 Stock Price is 9.424167134097855
#
# ###### WARNING ######
# Red Day: Price changed by:  2.422217872807767 %
# stock price is 9.424167134097855
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  102
#
#
# Day: 34 Stock Price is 9.439868197390116
#
# ###### WARNING ######
# Red Day: Price changed by:  0.16660425339288104 %
# stock price is 9.439868197390116
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  105
#
#
# Day: 35 Stock Price is 9.340969279997582
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.0476726509791294 %
# stock price is 9.340969279997582
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  108
#
#
# Day: 36 Stock Price is 9.430989513836519
#
# ###### WARNING ######
# Red Day: Price changed by:  0.9637140551538108 %
# stock price is 9.430989513836519
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  111
#
#
# Day: 37 Stock Price is 9.392268098148973
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.4105763836417813 %
# stock price is 9.392268098148973
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  114
#
#
# Day: 38 Stock Price is 9.358200894777877
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.36271540606693264 %
# stock price is 9.358200894777877
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  117
#
#
# Day: 39 Stock Price is 9.477237625393078
#
# ###### WARNING ######
# Red Day: Price changed by:  1.2720044371095558 %
# stock price is 9.477237625393078
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  120
#
#
# Day: 40 Stock Price is 9.196103125902255
#
# ###### WARNING ######
# Red Day: Price changed by:  -2.9664181758781623 %
# stock price is 9.196103125902255
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  123
#
#
# Day: 41 Stock Price is 9.684266956265482
#
# ###### WARNING ######
# Red Day: Price changed by:  5.308377077549706 %
# stock price is 9.684266956265482
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  126
#
#
# Day: 42 Stock Price is 9.858230382832192
#
# ###### WARNING ######
# Red Day: Price changed by:  1.7963510026348455 %
# stock price is 9.858230382832192
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  129
#
#
# Day: 43 Stock Price is 10.171083048606935
#
# ###### WARNING ######
# Red Day: Price changed by:  3.173517493764058 %
# stock price is 10.171083048606935
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  132
#
#
# Day: 44 Stock Price is 10.345221526325828
#
# ###### WARNING ######
# Red Day: Price changed by:  1.712093755273614 %
# stock price is 10.345221526325828
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  135
#
#
# Day: 45 Stock Price is 10.170130192530252
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.692485108704683 %
# stock price is 10.170130192530252
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  138
#
#
# Day: 46 Stock Price is 10.34518830017788
#
# ###### WARNING ######
# Red Day: Price changed by:  1.7212966238741387 %
# stock price is 10.34518830017788
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  141
#
#
# Day: 47 Stock Price is 10.789777605971407
#
# ###### WARNING ######
# Red Day: Price changed by:  4.297546771438496 %
# stock price is 10.789777605971407
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  144
#
#
# Day: 48 Stock Price is 11.147551351452616
#
# ###### WARNING ######
# Red Day: Price changed by:  3.3158583850996606 %
# stock price is 11.147551351452616
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  147
#
#
# Day: 49 Stock Price is 10.856894047942697
#
# ###### WARNING ######
# Red Day: Price changed by:  -2.607364562371303 %
# stock price is 10.856894047942697
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  150
#
#
# Day: 50 Stock Price is 11.175708474914725
#
# ###### WARNING ######
# Red Day: Price changed by:  2.936515964549178 %
# stock price is 11.175708474914725
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  153
#
#
# Day: 51 Stock Price is 11.219980828671254
#
# ###### WARNING ######
# Red Day: Price changed by:  0.39614807290207577 %
# stock price is 11.219980828671254
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  156
#
#
# Day: 52 Stock Price is 10.906017225741554
#
# ###### WARNING ######
# Red Day: Price changed by:  -2.79825436178469 %
# stock price is 10.906017225741554
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  159
#
#
# Day: 53 Stock Price is 10.800246855272663
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.9698349844821474 %
# stock price is 10.800246855272663
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  162
#
#
# Day: 54 Stock Price is 10.659519119928548
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.3030048037782718 %
# stock price is 10.659519119928548
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  165
#
#
# Day: 55 Stock Price is 10.55125971451459
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.0156124699055367 %
# stock price is 10.55125971451459
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  168
#
#
# Day: 56 Stock Price is 10.306020473998299
#
# ###### WARNING ######
# Red Day: Price changed by:  -2.3242650370830495 %
# stock price is 10.306020473998299
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  171
#
#
# Day: 57 Stock Price is 9.944684186877486
#
# ###### WARNING ######
# Red Day: Price changed by:  -3.5060699523395007 %
# stock price is 9.944684186877486
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  174
#
#
# Day: 58 Stock Price is 10.09060247412789
#
# ###### WARNING ######
# Red Day: Price changed by:  1.4672993582133986 %
# stock price is 10.09060247412789
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  177
#
#
# Day: 59 Stock Price is 10.082598580971759
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.0793202702876524 %
# stock price is 10.082598580971759
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  180
#
#
# Day: 60 Stock Price is 9.528357871004056
#
# ###### WARNING ######
# Red Day: Price changed by:  -5.4970026379279435 %
# stock price is 9.528357871004056
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  183
#
#
# Day: 61 Stock Price is 9.078798199133463
#
# ###### WARNING ######
# Red Day: Price changed by:  -4.718123290044118 %
# stock price is 9.078798199133463
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  186
#
#
# Day: 62 Stock Price is 9.03225074581615
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.5127050111297241 %
# stock price is 9.03225074581615
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  189
#
#
# Day: 63 Stock Price is 8.871545881897765
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.779233863639422 %
# stock price is 8.871545881897765
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  192
#
#
# Day: 64 Stock Price is 8.861905280841771
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.1086687842720285 %
# stock price is 8.861905280841771
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  195
#
#
# Day: 65 Stock Price is 9.102108224445063
#
# ###### WARNING ######
# Red Day: Price changed by:  2.7105112951565564 %
# stock price is 9.102108224445063
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  198
#
#
# Day: 66 Stock Price is 9.387353142401786
#
# ###### WARNING ######
# Red Day: Price changed by:  3.1338335133244657 %
# stock price is 9.387353142401786
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  201
#
#
# Day: 67 Stock Price is 9.74170668908215
#
# ###### WARNING ######
# Red Day: Price changed by:  3.774797233096332 %
# stock price is 9.74170668908215
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  204
#
#
# Day: 68 Stock Price is 9.537650240241929
#
# ###### WARNING ######
# Red Day: Price changed by:  -2.094668371291802 %
# stock price is 9.537650240241929
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  207
#
#
# Day: 69 Stock Price is 9.238394653033508
#
# ###### WARNING ######
# Red Day: Price changed by:  -3.1376238347028087 %
# stock price is 9.238394653033508
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  210
#
#
# Day: 70 Stock Price is 9.045713154408185
#
# ###### WARNING ######
# Red Day: Price changed by:  -2.0856599643321667 %
# stock price is 9.045713154408185
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  213
#
#
# Day: 71 Stock Price is 8.656144095413381
#
# ###### WARNING ######
# Red Day: Price changed by:  -4.306670489600447 %
# stock price is 8.656144095413381
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  216
#
#
# Day: 72 Stock Price is 8.668803891382858
#
# ###### WARNING ######
# Red Day: Price changed by:  0.14625213986658028 %
# stock price is 8.668803891382858
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  219
#
#
# Day: 73 Stock Price is 8.70742031172884
#
# ###### WARNING ######
# Red Day: Price changed by:  0.4454642281661001 %
# stock price is 8.70742031172884
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  222
#
#
# Day: 74 Stock Price is 8.358169911920442
#
# ###### WARNING ######
# Red Day: Price changed by:  -4.010951433433839 %
# stock price is 8.358169911920442
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  225
#
#
# Day: 75 Stock Price is 7.936639876383425
#
# ###### WARNING ######
# Red Day: Price changed by:  -5.043329340982043 %
# stock price is 7.936639876383425
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  228
#
#
# Day: 76 Stock Price is 7.472946298281335
#
# ###### WARNING ######
# Red Day: Price changed by:  -5.842441956852226 %
# stock price is 7.472946298281335
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  231
#
#
# Day: 77 Stock Price is 7.669563318168493
#
# ###### WARNING ######
# Red Day: Price changed by:  2.6310508872835943 %
# stock price is 7.669563318168493
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  234
#
#
# Day: 78 Stock Price is 7.494752529217713
#
# ###### WARNING ######
# Red Day: Price changed by:  -2.2792795586766745 %
# stock price is 7.494752529217713
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  237
#
#
# Day: 79 Stock Price is 7.113288174342916
#
# ###### WARNING ######
# Red Day: Price changed by:  -5.089752508674414 %
# stock price is 7.113288174342916
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  240
#
#
# Day: 80 Stock Price is 7.185329655501164
#
# ###### WARNING ######
# Red Day: Price changed by:  1.012773268740832 %
# stock price is 7.185329655501164
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  243
#
#
# Day: 81 Stock Price is 6.85240450422024
#
# ###### WARNING ######
# Red Day: Price changed by:  -4.63340121111956 %
# stock price is 6.85240450422024
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  246
#
#
# Day: 82 Stock Price is 7.259016366863873
#
# ###### WARNING ######
# Red Day: Price changed by:  5.933856683346856 %
# stock price is 7.259016366863873
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  249
#
#
# Day: 83 Stock Price is 7.281253795466704
#
# ###### WARNING ######
# Red Day: Price changed by:  0.3063421747378873 %
# stock price is 7.281253795466704
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  252
#
#
# Day: 84 Stock Price is 7.535424618095943
#
# ###### WARNING ######
# Red Day: Price changed by:  3.4907562594162793 %
# stock price is 7.535424618095943
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  255
#
#
# Day: 85 Stock Price is 7.451250750379764
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.117042130765133 %
# stock price is 7.451250750379764
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  258
#
#
# Day: 86 Stock Price is 7.284913968330721
#
# ###### WARNING ######
# Red Day: Price changed by:  -2.2323337063990882 %
# stock price is 7.284913968330721
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  261
#
#
# Day: 87 Stock Price is 7.098596695410676
#
# ###### WARNING ######
# Red Day: Price changed by:  -2.557576846205877 %
# stock price is 7.098596695410676
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  264
#
#
# Day: 88 Stock Price is 7.3378206559331804
#
# ###### WARNING ######
# Red Day: Price changed by:  3.3700176356992517 %
# stock price is 7.3378206559331804
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  267
#
#
# Day: 89 Stock Price is 8.129155540215699
#
# ###### WARNING ######
# Red Day: Price changed by:  10.784331225684344 %
# stock price is 8.129155540215699
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  270
#
#
# Day: 90 Stock Price is 8.105354218411152
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.292789597723874 %
# stock price is 8.105354218411152
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  273
#
#
# Day: 91 Stock Price is 8.193730980786087
#
# ###### WARNING ######
# Red Day: Price changed by:  1.090350402875537 %
# stock price is 8.193730980786087
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  276
#
#
# Day: 92 Stock Price is 8.23423015951154
#
# ###### WARNING ######
# Red Day: Price changed by:  0.49427030031155184 %
# stock price is 8.23423015951154
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  279
#
#
# Day: 93 Stock Price is 8.196360160556011
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.4599094052743247 %
# stock price is 8.196360160556011
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  282
#
#
# Day: 94 Stock Price is 8.191630958364517
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.057698808969537684 %
# stock price is 8.191630958364517
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  285
#
#
# Day: 95 Stock Price is 8.328171595047545
#
# ###### WARNING ######
# Red Day: Price changed by:  1.6668309079964738 %
# stock price is 8.328171595047545
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  288
#
#
# Day: 96 Stock Price is 8.249100973711734
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.9494355445657623 %
# stock price is 8.249100973711734
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  291
#
#
# Day: 97 Stock Price is 8.53612070371701
#
# ###### WARNING ######
# Red Day: Price changed by:  3.479406191292274 %
# stock price is 8.53612070371701
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  294
#
#
# Day: 98 Stock Price is 8.882749222486876
#
# ###### WARNING ######
# Red Day: Price changed by:  4.060726538448863 %
# stock price is 8.882749222486876
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  297
#
#
# Day: 99 Stock Price is 8.745621610186088
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.5437519270908369 %
# stock price is 8.745621610186088
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  300
#
#
# Day: 100 Stock Price is 8.75591366011786
#
# ###### WARNING ######
# Red Day: Price changed by:  0.11768231453994007 %
# stock price is 8.75591366011786
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  303
#
#
# Day: 101 Stock Price is 8.58997074027302
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.8952096410074275 %
# stock price is 8.58997074027302
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  306
#
#
# Day: 102 Stock Price is 8.631192384494678
#
# ###### WARNING ######
# Red Day: Price changed by:  0.4798810783882491 %
# stock price is 8.631192384494678
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  309
#
#
# Day: 103 Stock Price is 8.704399419151125
#
# ###### WARNING ######
# Red Day: Price changed by:  0.8481682645373236 %
# stock price is 8.704399419151125
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  312
#
#
# Day: 104 Stock Price is 8.51266064898249
#
# ###### WARNING ######
# Red Day: Price changed by:  -2.2027800073923336 %
# stock price is 8.51266064898249
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  315
#
#
# Day: 105 Stock Price is 8.645271238433667
#
# ###### WARNING ######
# Red Day: Price changed by:  1.5578042508604926 %
# stock price is 8.645271238433667
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  318
#
#
# Day: 106 Stock Price is 8.774032999503445
#
# ###### WARNING ######
# Red Day: Price changed by:  1.4893894884101777 %
# stock price is 8.774032999503445
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  321
#
#
# Day: 107 Stock Price is 9.24486165689036
#
# ###### WARNING ######
# Red Day: Price changed by:  5.366160093238312 %
# stock price is 9.24486165689036
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  324
#
#
# Day: 108 Stock Price is 9.074632561104167
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.841337405620526 %
# stock price is 9.074632561104167
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  327
#
#
# Day: 109 Stock Price is 9.05980508226573
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.16339481228133867 %
# stock price is 9.05980508226573
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  330
#
#
# Day: 110 Stock Price is 9.412802027206112
#
# ###### WARNING ######
# Red Day: Price changed by:  3.89629734563895 %
# stock price is 9.412802027206112
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  333
#
#
# Day: 111 Stock Price is 9.074601061193695
#
# ###### WARNING ######
# Red Day: Price changed by:  -3.5929892611669145 %
# stock price is 9.074601061193695
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  336
#
#
# Day: 112 Stock Price is 8.758718678594084
#
# ###### WARNING ######
# Red Day: Price changed by:  -3.480950627685879 %
# stock price is 8.758718678594084
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  339
#
#
# Day: 113 Stock Price is 8.70271524452732
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.6394021331411652 %
# stock price is 8.70271524452732
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  342
#
#
# Day: 114 Stock Price is 8.861052181753255
#
# ###### WARNING ######
# Red Day: Price changed by:  1.8193969672339192 %
# stock price is 8.861052181753255
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  345
#
#
# Day: 115 Stock Price is 9.00545727866552
#
# ###### WARNING ######
# Red Day: Price changed by:  1.6296608342926355 %
# stock price is 9.00545727866552
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  348
#
#
# Day: 116 Stock Price is 8.551952683776308
#
# ###### WARNING ######
# Red Day: Price changed by:  -5.035886361524267 %
# stock price is 8.551952683776308
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  351
#
#
# Day: 117 Stock Price is 8.91629310600979
#
# ###### WARNING ######
# Red Day: Price changed by:  4.260318499243601 %
# stock price is 8.91629310600979
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  354
#
#
# Day: 118 Stock Price is 8.784232424082315
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.4811164276156892 %
# stock price is 8.784232424082315
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  357
#
#
# Day: 119 Stock Price is 8.551619492630056
#
# ###### WARNING ######
# Red Day: Price changed by:  -2.648073505142478 %
# stock price is 8.551619492630056
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  360
#
#
# Day: 120 Stock Price is 8.792380362489896
#
# ###### WARNING ######
# Red Day: Price changed by:  2.815383332564451 %
# stock price is 8.792380362489896
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  363
#
#
# Day: 121 Stock Price is 8.936769275663348
#
# ###### WARNING ######
# Red Day: Price changed by:  1.6422050368685723 %
# stock price is 8.936769275663348
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  366
#
#
# Day: 122 Stock Price is 9.39418205893297
#
# ###### WARNING ######
# Red Day: Price changed by:  5.118323738257961 %
# stock price is 9.39418205893297
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  369
#
#
# Day: 123 Stock Price is 8.941715352057141
#
# ###### WARNING ######
# Red Day: Price changed by:  -4.816456654100892 %
# stock price is 8.941715352057141
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  372
#
#
# Day: 124 Stock Price is 8.900247615415175
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.4637559462505832 %
# stock price is 8.900247615415175
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  375
#
#
# Day: 125 Stock Price is 8.812020579699404
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.9912874284863944 %
# stock price is 8.812020579699404
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  378
#
#
# Day: 126 Stock Price is 8.928035207619006
#
# ###### WARNING ######
# Red Day: Price changed by:  1.3165496706495388 %
# stock price is 8.928035207619006
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  381
#
#
# Day: 127 Stock Price is 8.888471796509963
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.4431368177768906 %
# stock price is 8.888471796509963
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  384
#
#
# Day: 128 Stock Price is 8.26200443972357
#
# ###### WARNING ######
# Red Day: Price changed by:  -7.048088480545932 %
# stock price is 8.26200443972357
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  387
#
#
# Day: 129 Stock Price is 8.438666030823168
#
# ###### WARNING ######
# Red Day: Price changed by:  2.1382412995351414 %
# stock price is 8.438666030823168
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  390
#
#
# Day: 130 Stock Price is 8.324387113730628
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.3542296457179783 %
# stock price is 8.324387113730628
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  393
#
#
# Day: 131 Stock Price is 8.408112861093665
#
# ###### WARNING ######
# Red Day: Price changed by:  1.0057887291778664 %
# stock price is 8.408112861093665
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  396
#
#
# Day: 132 Stock Price is 8.303270852557533
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.2469148579256084 %
# stock price is 8.303270852557533
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  399
#
#
# Day: 133 Stock Price is 8.32563908953247
#
# ###### WARNING ######
# Red Day: Price changed by:  0.2693906699195137 %
# stock price is 8.32563908953247
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  402
#
#
# Day: 134 Stock Price is 8.17247750805785
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.8396375320566498 %
# stock price is 8.17247750805785
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  405
#
#
# Day: 135 Stock Price is 8.290077460494818
#
# ###### WARNING ######
# Red Day: Price changed by:  1.4389755410279976 %
# stock price is 8.290077460494818
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  408
#
#
# Day: 136 Stock Price is 8.275018276409599
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.18165311671672152 %
# stock price is 8.275018276409599
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  411
#
#
# Day: 137 Stock Price is 8.345210082837724
#
# ###### WARNING ######
# Red Day: Price changed by:  0.8482374791633671 %
# stock price is 8.345210082837724
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  414
#
#
# Day: 138 Stock Price is 8.413278581697746
#
# ###### WARNING ######
# Red Day: Price changed by:  0.8156595002923652 %
# stock price is 8.413278581697746
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  417
#
#
# Day: 139 Stock Price is 8.700180613564765
#
# ###### WARNING ######
# Red Day: Price changed by:  3.410109734047634 %
# stock price is 8.700180613564765
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  420
#
#
# Day: 140 Stock Price is 8.83578033626117
#
# ###### WARNING ######
# Red Day: Price changed by:  1.5585851457495736 %
# stock price is 8.83578033626117
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  423
#
#
# Day: 141 Stock Price is 9.037628483929456
#
# ###### WARNING ######
# Red Day: Price changed by:  2.284440535941373 %
# stock price is 9.037628483929456
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  426
#
#
# Day: 142 Stock Price is 8.905405315786187
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.4630294703791606 %
# stock price is 8.905405315786187
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  429
#
#
# Day: 143 Stock Price is 8.446682058381368
#
# ###### WARNING ######
# Red Day: Price changed by:  -5.151065461239167 %
# stock price is 8.446682058381368
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  432
#
#
# Day: 144 Stock Price is 8.277813404994898
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.9992306117276761 %
# stock price is 8.277813404994898
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  435
#
#
# Day: 145 Stock Price is 8.17530359549328
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.2383682077173077 %
# stock price is 8.17530359549328
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  438
#
#
# Day: 146 Stock Price is 7.813065791606852
#
# ###### WARNING ######
# Red Day: Price changed by:  -4.430878922785384 %
# stock price is 7.813065791606852
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  441
#
#
# Day: 147 Stock Price is 7.737604031238721
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.9658405852565015 %
# stock price is 7.737604031238721
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  444
#
#
# Day: 148 Stock Price is 8.162910548737674
#
# ###### WARNING ######
# Red Day: Price changed by:  5.496617761543247 %
# stock price is 8.162910548737674
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  447
#
#
# Day: 149 Stock Price is 7.962565572273798
#
# ###### WARNING ######
# Red Day: Price changed by:  -2.4543326215287062 %
# stock price is 7.962565572273798
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  450
#
#
# Day: 150 Stock Price is 8.110869522952902
#
# ###### WARNING ######
# Red Day: Price changed by:  1.862514654767899 %
# stock price is 8.110869522952902
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  453
#
#
# Day: 151 Stock Price is 8.026786047202759
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.036676468684345 %
# stock price is 8.026786047202759
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  456
#
#
# Day: 152 Stock Price is 8.116165936614001
#
# ###### WARNING ######
# Red Day: Price changed by:  1.1135202668369457 %
# stock price is 8.116165936614001
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  459
#
#
# Day: 153 Stock Price is 8.358032389898549
#
# ###### WARNING ######
# Red Day: Price changed by:  2.980058012286686 %
# stock price is 8.358032389898549
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  462
#
#
# Day: 154 Stock Price is 8.648861236776053
#
# ###### WARNING ######
# Red Day: Price changed by:  3.479632924478702 %
# stock price is 8.648861236776053
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  465
#
#
# Day: 155 Stock Price is 8.49961959489035
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.725564069071993 %
# stock price is 8.49961959489035
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  468
#
#
# Day: 156 Stock Price is 8.05427059096992
#
# ###### WARNING ######
# Red Day: Price changed by:  -5.2396345383286915 %
# stock price is 8.05427059096992
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  471
#
#
# Day: 157 Stock Price is 7.983493900065727
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.8787473689243261 %
# stock price is 7.983493900065727
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  474
#
#
# Day: 158 Stock Price is 8.058473869544368
#
# ###### WARNING ######
# Red Day: Price changed by:  0.9391874086360072 %
# stock price is 8.058473869544368
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  477
#
#
# Day: 159 Stock Price is 7.920755145765318
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.7089926207930661 %
# stock price is 7.920755145765318
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  480
#
#
# Day: 160 Stock Price is 7.898042804482308
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.28674464574445063 %
# stock price is 7.898042804482308
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  483
#
#
# Day: 161 Stock Price is 7.957704878700007
#
# ###### WARNING ######
# Red Day: Price changed by:  0.7554032776808914 %
# stock price is 7.957704878700007
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  486
#
#
# Day: 162 Stock Price is 8.136018090038656
#
# ###### WARNING ######
# Red Day: Price changed by:  2.240761803267303 %
# stock price is 8.136018090038656
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  489
#
#
# Day: 163 Stock Price is 8.044186839180165
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.128700180385828 %
# stock price is 8.044186839180165
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  492
#
#
# Day: 164 Stock Price is 8.137966205792074
#
# ###### WARNING ######
# Red Day: Price changed by:  1.1658029392746627 %
# stock price is 8.137966205792074
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  495
#
#
# Day: 165 Stock Price is 8.508855094005702
#
# ###### WARNING ######
# Red Day: Price changed by:  4.557513251279574 %
# stock price is 8.508855094005702
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  498
#
#
# Day: 166 Stock Price is 8.151552734936866
#
# ###### WARNING ######
# Red Day: Price changed by:  -4.199182558891463 %
# stock price is 8.151552734936866
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  501
#
#
# Day: 167 Stock Price is 8.615543497969131
#
# ###### WARNING ######
# Red Day: Price changed by:  5.692053748774034 %
# stock price is 8.615543497969131
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  504
#
#
# Day: 168 Stock Price is 8.975129325148721
#
# ###### WARNING ######
# Red Day: Price changed by:  4.173687095472863 %
# stock price is 8.975129325148721
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  507
#
#
# Day: 169 Stock Price is 8.95627442544133
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.21007942085644862 %
# stock price is 8.95627442544133
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  510
#
#
# Day: 170 Stock Price is 8.928573023058641
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.30929604282781775 %
# stock price is 8.928573023058641
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  513
#
#
# Day: 171 Stock Price is 9.456878077473945
#
# ###### WARNING ######
# Red Day: Price changed by:  5.917015552775577 %
# stock price is 9.456878077473945
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  516
#
#
# Day: 172 Stock Price is 9.301022265468614
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.6480683236952758 %
# stock price is 9.301022265468614
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  519
#
#
# Day: 173 Stock Price is 9.68918730022621
#
# ###### WARNING ######
# Red Day: Price changed by:  4.173358838186151 %
# stock price is 9.68918730022621
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  522
#
#
# Day: 174 Stock Price is 9.197130463720404
#
# ###### WARNING ######
# Red Day: Price changed by:  -5.078411854978986 %
# stock price is 9.197130463720404
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  525
#
#
# Day: 175 Stock Price is 8.99593336855341
#
# ###### WARNING ######
# Red Day: Price changed by:  -2.1876072755589115 %
# stock price is 8.99593336855341
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  528
#
#
# Day: 176 Stock Price is 9.203229940069903
#
# ###### WARNING ######
# Red Day: Price changed by:  2.3043364487461324 %
# stock price is 9.203229940069903
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  531
#
#
# Day: 177 Stock Price is 8.612589750756001
#
# ###### WARNING ######
# Red Day: Price changed by:  -6.417748911632828 %
# stock price is 8.612589750756001
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  534
#
#
# Day: 178 Stock Price is 8.601477911605558
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.12901855855223265 %
# stock price is 8.601477911605558
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  537
#
#
# Day: 179 Stock Price is 8.285263149125726
#
# ###### WARNING ######
# Red Day: Price changed by:  -3.676284072684517 %
# stock price is 8.285263149125726
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  540
#
#
# Day: 180 Stock Price is 8.204202010314235
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.9783773593243517 %
# stock price is 8.204202010314235
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  543
#
#
# Day: 181 Stock Price is 8.314878791817097
#
# ###### WARNING ######
# Red Day: Price changed by:  1.3490255525609993 %
# stock price is 8.314878791817097
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  546
#
#
# Day: 182 Stock Price is 8.093424524158449
#
# ###### WARNING ######
# Red Day: Price changed by:  -2.663349318772855 %
# stock price is 8.093424524158449
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  549
#
#
# Day: 183 Stock Price is 8.00663288409125
#
# ###### WARNING ######
# Red Day: Price changed by:  -1.0723722672415164 %
# stock price is 8.00663288409125
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  552
#
#
# Day: 184 Stock Price is 8.299530081938546
#
# ###### WARNING ######
# Red Day: Price changed by:  3.6581819359954233 %
# stock price is 8.299530081938546
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  555
#
#
# Day: 185 Stock Price is 8.418048314778739
#
# ###### WARNING ######
# Red Day: Price changed by:  1.4280113653435897 %
# stock price is 8.418048314778739
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  558
#
#
# Day: 186 Stock Price is 8.93594522615173
#
# ###### WARNING ######
# Red Day: Price changed by:  6.152220704931948 %
# stock price is 8.93594522615173
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  561
#
#
# Day: 187 Stock Price is 8.992124639017533
#
# ###### WARNING ######
# Red Day: Price changed by:  0.6286902106493301 %
# stock price is 8.992124639017533
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  564
#
#
# Day: 188 Stock Price is 9.093392114651726
#
# ###### WARNING ######
# Red Day: Price changed by:  1.1261796260561823 %
# stock price is 9.093392114651726
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  567
#
#
# Day: 189 Stock Price is 9.199129538705462
#
# ###### WARNING ######
# Red Day: Price changed by:  1.1627940676105408 %
# stock price is 9.199129538705462
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  570
#
#
# Day: 190 Stock Price is 8.69478157124613
#
# ###### WARNING ######
# Red Day: Price changed by:  -5.482561859111561 %
# stock price is 8.69478157124613
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  573
#
#
# Day: 191 Stock Price is 8.705631151910321
#
# ###### WARNING ######
# Red Day: Price changed by:  0.12478267079268435 %
# stock price is 8.705631151910321
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  576
#
#
# Day: 192 Stock Price is 8.284024599537565
#
# ###### WARNING ######
# Red Day: Price changed by:  -4.842917704826507 %
# stock price is 8.284024599537565
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  579
#
#
# Day: 193 Stock Price is 7.885138972108627
#
# ###### WARNING ######
# Red Day: Price changed by:  -4.815118818589752 %
# stock price is 7.885138972108627
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  582
#
#
# Day: 194 Stock Price is 7.87577107395343
#
# ###### WARNING ######
# Red Day: Price changed by:  -0.11880447749028641 %
# stock price is 7.87577107395343
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  585
#
#
# Day: 195 Stock Price is 8.036397928661003
#
# ###### WARNING ######
# Red Day: Price changed by:  2.03950639498391 %
# stock price is 8.036397928661003
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  588
#
#
# Day: 196 Stock Price is 8.217682928333513
#
# ###### WARNING ######
# Red Day: Price changed by:  2.2557991936409194 %
# stock price is 8.217682928333513
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  591
#
#
# Day: 197 Stock Price is 8.374144965755923
#
# ###### WARNING ######
# Red Day: Price changed by:  1.903967806824831 %
# stock price is 8.374144965755923
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  594
#
#
# Day: 198 Stock Price is 8.002138317365521
#
# ###### WARNING ######
# Red Day: Price changed by:  -4.44232396157022 %
# stock price is 8.002138317365521
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  597
#
#
# Day: 199 Stock Price is 7.679180792708033
#
# ###### WARNING ######
# Red Day: Price changed by:  -4.035890306427653 %
# stock price is 7.679180792708033
# Let's buy just 3 stocks
# Now total stocks in our portfolio is:  600
#
#
#
#
# Total stocks bought 600
# Total cost 5315.986822097836
# Cost per stock =8.859978036829727
# Current stock price: 7.679180792708033

# %%
import random
import numpy as np
from matplotlib import pyplot as plt
import os



def sim(stock_price,total_days):
    initial_stock_price=stock_price
    initial_stocks=0
    portfolio=initial_stocks
    cost=0
    price_history=np.zeros(total_days)
    days=np.arange(0,total_days,1)
    for i in range(total_days):
        percentage_change=np.random.normal(0.2,4.5,1)[0]
        stock_price=stock_price+(stock_price*percentage_change*0.01)
        price_history[i]=stock_price
        #print(f"Day: {i} Stock Price is {stock_price}")
        if percentage_change<100:
            buy=3
            cost+=buy*stock_price
            portfolio+=3
                
    #cost_basis=cost/portfolio
    '''
    print("Initial Stock Price:",initial_stock_price)
    print("Current Stock Price:",stock_price)
    print("\n\nTotal stocks bought",portfolio)
    print("Total cost",cost)
    print("Current price per stock:",cost_basis)
    #plt.plot(days,price_history)
    '''
    profit=(portfolio*stock_price)-cost
    return profit


n=10000
positive_profits_count=0
profits=np.zeros(n)

for i in range(n):
    os.system("cls")
    profits[i]=sim(10,1000)
    if profits[i]>0:
        positive_profits_count+=1

print("Positive Profits:",positive_profits_count)
print("Negative Profits:",n-positive_profits_count)
print("Mean profit:",np.mean(profits))
print("Standard Deviatin of profits:",np.std(profits))
print("Highest Profit:",np.max(profits))
print("Lowest Profit:",np.min(profits))
n,bins,edges=plt.hist(profits,bins=10)
plt.xticks(bins)
# Out:
# Positive Profits: 6832
# Negative Profits: 3168
# Mean profit: 123795.62756262577
# Standard Deviatin of profits: 365609.3933364309
# Highest Profit: 11407307.82550394
# Lowest Profit: -321313.8680941735
# ([<matplotlib.axis.XTick at 0x7f18842e54d0>,
#   <matplotlib.axis.XTick at 0x7f18842dcbd0>,
#   <matplotlib.axis.XTick at 0x7f18842dc8d0>,
#   <matplotlib.axis.XTick at 0x7f18842ffe50>,
#   <matplotlib.axis.XTick at 0x7f18842a2c90>,
#   <matplotlib.axis.XTick at 0x7f18842ab290>,
#   <matplotlib.axis.XTick at 0x7f18842a2e10>,
#   <matplotlib.axis.XTick at 0x7f18842abad0>,
#   <matplotlib.axis.XTick at 0x7f18842b1190>,
#   <matplotlib.axis.XTick at 0x7f18842b1790>,
#   <matplotlib.axis.XTick at 0x7f18842b1d90>],
#  <a list of 11 Text xticklabel objects>)
